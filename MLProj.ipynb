# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("cardio_train.csv", sep=";")

# %%
df.head(5)
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
df.tail()
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# 69995      1     0       1       0
# 69996      0     0       1       1
# 69997      0     1       0       1
# 69998      0     0       0       1
# 69999      0     0       1       0

# %%
df.shape
# Out:
# (70000, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           70000 non-null  int64
#  1   age          70000 non-null  int64
#  2   gender       70000 non-null  int64
#  3   height       70000 non-null  int64
#  4   weight       70000 non-null  float64
#  5   ap_hi        70000 non-null  int64
#  6   ap_lo        70000 non-null  int64
#  7   cholesterol  70000 non-null  int64
#  8   gluc         70000 non-null  int64
#  9   smoke        70000 non-null  int64
#  10  alco         70000 non-null  int64
#  11  active       70000 non-null  int64
#  12  cardio       70000 non-null  int64
# dtypes: float64(1), int64(12)
# memory usage: 6.9 MB

# %%
df.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900  19468.865814      1.349571    164.359229     74.205690
# std    28851.302323   2467.251667      0.476838      8.210126     14.395757
# min        0.000000  10798.000000      1.000000     55.000000     10.000000
# 25%    25006.750000  17664.000000      1.000000    159.000000     65.000000
# 50%    50001.500000  19703.000000      1.000000    165.000000     72.000000
# 75%    74889.250000  21327.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      2.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630414      1.366871      1.226457      0.088129
# ...

# %%
df.isnull().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["cardio"].value_counts()
# Out:
# cardio
# 0    35021
# 1    34979
# Name: count, dtype: int64

# %%
plt.hist(df["age"])
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
df.groupby("cardio")["age"].mean()
# Out:
# cardio
# 0    18881.623711
# 1    20056.813031
# Name: age, dtype: float64

# %%
df["gender"].value_counts().plot(kind="bar")
plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %%
df["cardio"].value_counts().plot(kind="bar")
plt.title("Cardiovascular Disease")
plt.xlabel("Cardio")
plt.ylabel("Count")
plt.show()

# %%
print("Minimum Age:", int(df["age"].min() / 365), "years")
print("Maximum Age:", int(df["age"].max() / 365), "years")
# Out:
# Minimum Age: 29 years
# Maximum Age: 64 years

# %%
plt.scatter(df["height"], df["weight"])

plt.title("Height vs Weight")
plt.xlabel("Height")
plt.ylabel("Weight")

plt.show()

# %%
df["smoke"].value_counts()
# Out:
# smoke
# 0    63831
# 1     6169
# Name: count, dtype: int64

# %%
df["age_years"] = df["age"] / 365

# %%
df[["age", "age_years"]].head()
# Out:
#      age  age_years
# 0  18393  50.391781
# 1  20228  55.419178
# 2  18857  51.663014
# 3  17623  48.282192
# 4  17474  47.873973

# %%
x = df[['gender', 'height', 'weight', 'ap_hi', 'ap_lo',
        'cholesterol', 'gluc', 'smoke', 'alco', 'active',
        'age_years']]

y = df['cardio']

# %%
print("Features shape:", x.shape)
print("Target shape:", y.shape)
# Out:
# Features shape: (70000, 11)
# Target shape: (70000,)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    x,
    y,
    test_size=0.2,
    random_state=42,
    stratify=y
)

print("Training data:", x_train.shape)
print("Testing data :", x_test.shape)
# Out:
# Training data: (56000, 11)
# Testing data : (14000, 11)

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

rf.fit(x_train, y_train)

print("rf Trained successfully")
# Out:
# Random Forest trained successfully

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

y_pred = rf.predict(x_test)

print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall   :", recall_score(y_test, y_pred))
print("F1-Score :", f1_score(y_test, y_pred))
# Out:
# Accuracy : 0.7155714285714285
# Precision: 0.7203860778005264
# Recall   : 0.7041166380789022
# F1-Score : 0.7121584501951713

# %%
train_score = rf.score(x_train, y_train)
test_score = rf.score(x_test, y_test)

print("Train Score:", train_score)
print("Test Score:", test_score)
print("Score Gap:", train_score - test_score)
# Out:
# Train Score: 0.9997678571428571
# Test Score : 0.7155714285714285
# Score Gap  : 0.28419642857142857

# %%
from sklearn.model_selection import cross_val_score

cv_scores = cross_val_score(
    rf,
    x_train,
    y_train,
    cv=5,
    scoring='accuracy'
)

print("CV Scores:", cv_scores)
print("Average CV Score:", cv_scores.mean())
print("Score Spread:", cv_scores.max() - cv_scores.min())
# Out:
# CV Scores: [0.714375   0.72080357 0.71303571 0.71401786 0.72169643]
# Average CV Score: 0.7167857142857144
# Score Spread: 0.008660714285714244

# %%
from sklearn.ensemble import AdaBoostClassifier

ada = AdaBoostClassifier(
    n_estimators=100,
    random_state=42
)

ada.fit(x_train, y_train)

print("AdaBoost trained successfully")
# Out:
# AdaBoost trained successfully

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

y_pred_ada = ada.predict(x_test)

accuracy = accuracy_score(y_test, y_pred_ada)
precision = precision_score(y_test, y_pred_ada)
recall = recall_score(y_test, y_pred_ada)
f1 = f1_score(y_test, y_pred_ada)

print("AdaBoost Accuracy :", accuracy)
print("AdaBoost Precision:", precision)
print("AdaBoost Recall   :", recall)
print("AdaBoost F1-score :", f1)
# Out:
# AdaBoost Accuracy : 0.7245714285714285
# AdaBoost Precision: 0.7621035058430717
# AdaBoost Recall   : 0.6525157232704403
# AdaBoost F1-score : 0.7030648390574464

# %%
from sklearn.model_selection import GridSearchCV

param_grid_rf = {
    'max_depth': [10, 15, 20],
    'min_samples_leaf': [2, 5, 10],
    'n_estimators': [100]
}

grid_rf = GridSearchCV(
    estimator=RandomForestClassifier(random_state=42, n_jobs=-1),
    param_grid=param_grid_rf,
    cv=3,
    scoring='accuracy',
    n_jobs=-1
)
grid_rf.fit(x_train, y_train)

print('Best Random Forest Parameters:', grid_rf.best_params_)
best_rf = grid_rf.best_estimator_

rf_tuned_train = best_rf.score(x_train, y_train)
rf_tuned_test = best_rf.score(x_test, y_test)
print(f'Tuned RF Train Score : {rf_tuned_train * 100:.2f}%')
print(f'Tuned RF Test Score  : {rf_tuned_test * 100:.2f}%')
print(f'Overfitting Gap      : {(rf_tuned_train - rf_tuned_test) * 100:.2f}% (Reduced from 28.42%!)')

# %%
param_grid_ada = {
    'n_estimators': [50, 100, 150],
    'learning_rate': [0.5, 0.8, 1.0]
}
grid_ada = GridSearchCV(
    estimator=AdaBoostClassifier(random_state=42),
    param_grid=param_grid_ada,
    cv=3,
    scoring='accuracy',
    n_jobs=-1
)
grid_ada.fit(x_train, y_train)

print('Best AdaBoost Parameters:', grid_ada.best_params_)
best_ada = grid_ada.best_estimator_
print(f'Tuned AdaBoost Test Score: {best_ada.score(x_test, y_test) * 100:.2f}%')
